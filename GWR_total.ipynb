# %%
import numpy as np
import libpysal as ps
from mgwr.gwr import GWR, MGWR
from mgwr.sel_bw import Sel_BW
import geopandas as gp
import matplotlib.pyplot as plt
import matplotlib as mpl

import os

# %%
import esda
import pandas as pd
import geopandas as gpd
import seaborn as sns
from geopandas import GeoDataFrame
import libpysal as lps
import numpy as np
import matplotlib.pyplot as plt
from shapely.geometry import Point
import contextily as ctx
from pylab import figure, scatter, show
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# # loading file

# %%
#read london borough
boros = gpd.read_file('statistical-gis-boundaries-london/statistical-gis-boundaries-london/ESRI/London_Borough_Excluding_MHW.shp')

# %%
ldn = gpd.GeoDataFrame(gpd.GeoSeries(data=boros.unary_union, crs='epsg:27700')).rename(columns={0:'original'})
# buffer the boundary by 250m
ldn['geometry'] = ldn.original.buffer(250)
ldn = ldn.set_geometry('geometry')
ldn.plot();

# %%
#lSOA Shapefile 
lsoas = gpd.read_file('statistical-gis-boundaries-london/statistical-gis-boundaries-london/ESRI/LSOA_2011_London_gen_MHW.shp')
lsoas.plot()
# Out:
# <AxesSubplot:>

# %%
green_acc = pd.read_csv("Data_firstclean/green_lsoa.csv",low_memory=False)

# %%
green_acc.head()
# Out:
#       lsoa11  blue_dist  green_pas  green_act
# 0  E01000001   2.387111   0.046221      0.295
# 1  E01000002   2.048814   0.041072      0.320
# 2  E01000003   1.217941   0.050611      0.200
# 3  E01000005   1.181282   0.044282      0.140
# 4  E01000006   1.760714   0.527459      0.585

# %%
lsoa_greenacc = pd.merge(lsoas, green_acc, left_on='LSOA11CD', right_on='lsoa11', how='left')
print(lsoa_greenacc.shape)
lsoa_greenacc
# Out:
# (4835, 19)
#        LSOA11CD                   LSOA11NM   MSOA11CD  \
# 0     E01000001        City of London 001A  E02000001
# 1     E01000002        City of London 001B  E02000001
# 2     E01000003        City of London 001C  E02000001
# 3     E01000005        City of London 001E  E02000001
# 4     E01000006  Barking and Dagenham 016A  E02000017
# ...         ...                        ...        ...
# 4830  E01033742             Greenwich 007F  E02000319
# 4831  E01033743             Greenwich 002H  E02000314
# 4832  E01033744             Greenwich 007G  E02000319
# 4833  E01033745             Greenwich 002I  E02000314
# 4834  E01033746             Greenwich 038E  E02006931
#
#                       MSOA11NM    LAD11CD               LAD11NM    RGN11CD  \
# 0           City of London 001  E09000001        City of London  E12000007
# 1           City of London 001  E09000001        City of London  E12000007
# 2           City of London 001  E09000001        City of London  E12000007
# 3           City of London 001  E09000001        City of London  E12000007
# 4     Barking and Dagenham 016  E09000002  Barking and Dagenham  E12000007
# ...                        ...        ...                   ...        ...
# 4830             Greenwich 007  E09000011             Greenwich  E12000007
# 4831             Greenwich 002  E09000011             Greenwich  E12000007
# 4832             Greenwich 007  E09000011             Greenwich  E12000007
# 4833             Greenwich 002  E09000011             Greenwich  E12000007
# 4834             Greenwich 038  E09000011             Greenwich  E12000007
#
#      RGN11NM  USUALRES  HHOLDRES  COMESTRES  POPDEN  HHOLDS  AVHHOLDSZ  \
# 0     London      1465      1465          0   112.9     876        1.7
# 1     London      1436      1436          0    62.9     830        1.7
# 2     London      1346      1250         96   227.7     817        1.5
# 3     London       985       985          0    52.0     467        2.1
# 4     London      1703      1699          4   116.2     543        3.1
# ...      ...       ...       ...        ...     ...     ...        ...
# 4830  London      1352      1352          0   107.6     581        2.3
# 4831  London      2038      2038          0    20.4     663        3.1
# 4832  London      1845      1728        117   125.8     646        2.7
# 4833  London      1820      1820          0    32.3     591        3.1
# 4834  London      1464      1436         28   115.3     715        2.0
#
#                                                geometry     lsoa11  blue_dist  \
# 0     POLYGON ((532105.092 182011.230, 532162.491 18...  E01000001   2.387111
# 1     POLYGON ((532746.813 181786.891, 532671.688 18...  E01000002   2.048814
# 2     POLYGON ((532135.145 182198.119, 532158.250 18...  E01000003   1.217941
# 3     POLYGON ((533807.946 180767.770, 533649.063 18...  E01000005   1.181282
# 4     POLYGON ((545122.049 184314.931, 545271.917 18...  E01000006   1.760714
# ...                                                 ...        ...        ...
# 4830  POLYGON ((544642.680 179824.674, 544766.313 17...  E01033742   0.185333
# 4831  POLYGON ((546579.195 181097.813, 546687.036 18...  E01033743   0.634500
# 4832  POLYGON ((544536.486 179447.115, 544602.630 17...  E01033744   0.273226
# 4833  POLYGON ((546415.745 180152.270, 546320.715 18...  E01033745   0.537037
# 4834  POLYGON ((538140.000 177313.000, 538129.177 17...  E01033746   1.281379
#
#       green_pas  green_act
# 0      0.046221      0.295
# 1      0.041072      0.320
# 2      0.050611      0.200
# 3      0.044282      0.140
# 4      0.527459      0.585
# ...         ...        ...
# 4830   0.039919      0.880
# 4831   0.067162      0.955
# 4832   0.015671      0.600
# 4833   0.104303      1.090
# 4834   1.551959      0.620
#
# [4835 rows x 19 columns]

# %%
boro_green2 = lsoa_greenacc.groupby(['LAD11CD'],as_index=False)['blue_dist','green_act','green_pas'].median()
boro_green2.head()
# Out:
#      LAD11CD  blue_dist  green_act  green_pas
# 0  E09000001   1.199612     0.3075   0.045252
# 1  E09000002   1.324479     0.3800   0.706887
# 2  E09000003   3.113437     0.4400   0.611714
# 3  E09000004   2.064403     0.4775   0.363154
# 4  E09000005   2.081429     0.3800   0.470558

# %%
#add green space with borough file
boro_greenacc = pd.merge(boros, boro_green2, left_on='GSS_CODE', right_on='LAD11CD', how='left')
print(boro_greenacc.shape)
boro_greenacc.head()
# Out:
# (33, 12)
#                    NAME   GSS_CODE   HECTARES  NONLD_AREA ONS_INNER SUB_2009  \
# 0  Kingston upon Thames  E09000021   3726.117       0.000         F     None
# 1               Croydon  E09000008   8649.441       0.000         F     None
# 2               Bromley  E09000006  15013.487       0.000         F     None
# 3              Hounslow  E09000018   5658.541      60.755         F     None
# 4                Ealing  E09000009   5554.428       0.000         F     None
#
#   SUB_2006                                           geometry    LAD11CD  \
# 0     None  POLYGON ((516401.600 160201.800, 516407.300 16...  E09000021
# 1     None  POLYGON ((535009.200 159504.700, 535005.500 15...  E09000008
# 2     None  POLYGON ((540373.600 157530.400, 540361.200 15...  E09000006
# 3     None  POLYGON ((521975.800 178100.000, 521967.700 17...  E09000018
# 4     None  POLYGON ((510253.500 182881.600, 510249.900 18...  E09000009
#
#    blue_dist  green_act  green_pas
# 0   3.443026    0.51207   0.464815
# 1   2.908372    0.50500   0.584036
# 2   2.637000    0.47000   0.478473
# 3   1.598901    0.38250   0.564246
# 4   2.013571    0.37750   0.553855

# %%
other = pd.read_csv("Data_firstclean/other_factors2.csv",low_memory=False)
other.head()
# Out:
#    Area_code             Area_name  obesity(age18+)  respiratory  coronary  \
# 0  E09000002  Barking and Dagenham          64.5155     133.0534  104.4367
# 1  E09000003                Barnet          61.1233      77.4378   88.5450
# 2  E09000004                Bexley          64.6095      88.3333   90.9369
# 3  E09000005                 Brent          55.8951      72.4171  103.4684
# 4  E09000006               Bromley          58.0292      83.4814   80.1178
#
#    TB_incidence  Active   Females  Populationdensity  housingprice  ...  \
# 0       20.6100   0.519  0.513476             6064.0      300000.0  ...
# 1       13.3525   0.616  0.516054             4487.0      533500.0  ...
# 2        8.8988   0.524  0.519270             4069.0      342500.0  ...
# 3       32.5362   0.557  0.509417             7859.0      499950.0  ...
# 4        5.2376   0.683  0.520303             2198.0      440000.0  ...
#
#    65+(100%)  All_persons  total_cases  ln_total_cases  total_cases2  \
# 0   0.086798       218900        71600       11.178850         27327
# 1   0.144105       389300       132459       11.794028         51285
# 2   0.166329       246500        85071       11.351241         35010
# 3   0.116245       339800       106510       11.575994         40930
# 4   0.176667       330000       114402       11.647474         47084
#
#    covid0_60  covid_60up  total_case_rate  infection_tate(60-)  \
# 0    65036.0      6633.0        32.708999            34.050262
# 1   115297.0     17370.0        34.024917            36.707100
# 2    72806.0     12377.0        34.511562            37.939552
# 3    93742.0     12837.0        31.344909            33.019373
# 4    98314.0     16263.0        34.667273            38.782643
#
#    infection_tate(60+)
# 0            24.032533
# 1            23.098360
# 2            22.668429
# 3            22.964174
# 4            21.231022
#
# [5 rows x 21 columns]

# %%
#add green space with borough file
boro_xy = pd.merge(boro_greenacc,other, left_on="GSS_CODE", right_on='Area_code', how='inner')
boro_xy.head()
# Out:
#                    NAME   GSS_CODE   HECTARES  NONLD_AREA ONS_INNER SUB_2009  \
# 0  Kingston upon Thames  E09000021   3726.117       0.000         F     None
# 1               Croydon  E09000008   8649.441       0.000         F     None
# 2               Bromley  E09000006  15013.487       0.000         F     None
# 3              Hounslow  E09000018   5658.541      60.755         F     None
# 4                Ealing  E09000009   5554.428       0.000         F     None
#
#   SUB_2006                                           geometry    LAD11CD  \
# 0     None  POLYGON ((516401.600 160201.800, 516407.300 16...  E09000021
# 1     None  POLYGON ((535009.200 159504.700, 535005.500 15...  E09000008
# 2     None  POLYGON ((540373.600 157530.400, 540361.200 15...  E09000006
# 3     None  POLYGON ((521975.800 178100.000, 521967.700 17...  E09000018
# 4     None  POLYGON ((510253.500 182881.600, 510249.900 18...  E09000009
#
#    blue_dist  ...  65+(100%)  All_persons total_cases ln_total_cases  \
# 0   3.443026  ...   0.144048       168000       63134      11.053015
# 1   2.908372  ...   0.135875       390800      130320      11.777748
# 2   2.637000  ...   0.176667       330000      114402      11.647474
# 3   1.598901  ...   0.117974       288200       98773      11.500580
# 4   2.013571  ...   0.121220       367100      124575      11.732663
#
#    total_cases2  covid0_60  covid_60up  total_case_rate  infection_tate(60-)  \
# 0         25388    55474.0      7745.0        37.579762            40.910030
# 1         54280   113581.0     16970.0        33.346981            35.796092
# 2         47084    98314.0     16263.0        34.667273            38.782643
# 3         37581    87660.0     11146.0        34.272380            36.373444
# 4         47256   109930.0     14669.0        33.934895            36.054444
#
#    infection_tate(60+)
# 0            23.904215
# 1            23.119848
# 2            21.231022
# 3            23.564423
# 4            23.621532
#
# [5 rows x 33 columns]

# %%
boro_xy.drop(["GSS_CODE","HECTARES","NONLD_AREA","ONS_INNER"],axis=1, inplace=True)

# %%
boro_xy=boro_xy.set_index("Area_code", drop=True, append=False, inplace=False, verify_integrity=False)
boro_xy.head()
# Out:
#                            NAME SUB_2009 SUB_2006  \
# Area_code
# E09000021  Kingston upon Thames     None     None
# E09000008               Croydon     None     None
# E09000006               Bromley     None     None
# E09000018              Hounslow     None     None
# E09000009                Ealing     None     None
#
#                                                     geometry    LAD11CD  \
# Area_code
# E09000021  POLYGON ((516401.600 160201.800, 516407.300 16...  E09000021
# E09000008  POLYGON ((535009.200 159504.700, 535005.500 15...  E09000008
# E09000006  POLYGON ((540373.600 157530.400, 540361.200 15...  E09000006
# E09000018  POLYGON ((521975.800 178100.000, 521967.700 17...  E09000018
# E09000009  POLYGON ((510253.500 182881.600, 510249.900 18...  E09000009
#
#            blue_dist  green_act  green_pas             Area_name  \
# Area_code
# E09000021   3.443026    0.51207   0.464815  Kingston upon Thames
# E09000008   2.908372    0.50500   0.584036               Croydon
# E09000006   2.637000    0.47000   0.478473               Bromley
# E09000018   1.598901    0.38250   0.564246              Hounslow
# E09000009   2.013571    0.37750   0.553855                Ealing
#
#            obesity(age18+)  ...  65+(100%)  All_persons  total_cases  \
# Area_code                   ...
# E09000021          57.6050  ...   0.144048       168000        63134
# E09000008          61.8092  ...   0.135875       390800       130320
# E09000006          58.0292  ...   0.176667       330000       114402
# E09000018          63.2337  ...   0.117974       288200        98773
# E09000009          53.0091  ...   0.121220       367100       124575
#
#            ln_total_cases  total_cases2  covid0_60  covid_60up  \
# Area_code
# E09000021       11.053015         25388    55474.0      7745.0
# E09000008       11.777748         54280   113581.0     16970.0
# E09000006       11.647474         47084    98314.0     16263.0
# E09000018       11.500580         37581    87660.0     11146.0
# E09000009       11.732663         47256   109930.0     14669.0
#
#            total_case_rate  infection_tate(60-)  infection_tate(60+)
# Area_code
# E09000021        37.579762            40.910030            23.904215
# E09000008        33.346981            35.796092            23.119848
# E09000006        34.667273            38.782643            21.231022
# E09000018        34.272380            36.373444            23.564423
# E09000009        33.934895            36.054444            23.621532
#
# [5 rows x 28 columns]

# %%
boro_xy.drop(["LAD11CD","Area_name"],axis=1, inplace=True)

# %%
boro_xy.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 32 entries, E09000021 to E09000002
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   NAME                 32 non-null     object
#  1   SUB_2009             0 non-null      object
#  2   SUB_2006             0 non-null      object
#  3   geometry             32 non-null     geometry
#  4   blue_dist            32 non-null     float64
#  5   green_act            32 non-null     float64
#  6   green_pas            32 non-null     float64
#  7   obesity(age18+)      32 non-null     float64
#  8   respiratory          32 non-null     float64
#  9   coronary             32 non-null     float64
#  10  TB_incidence         32 non-null     float64
#  11  Active               32 non-null     float64
#  12  Females              32 non-null     float64
#  13  Populationdensity    32 non-null     float64
#  14  housingprice         32 non-null     float64
#  15  income               32 non-null     float64
#  16  65+(100%)            32 non-null     float64
#  17  All_persons          32 non-null     int64
#  18  total_cases          32 non-null     int64
#  19  ln_total_cases       32 non-null     float64
#  20  total_cases2         32 non-null     int64
#  21  covid0_60            32 non-null     float64
#  22  covid_60up           32 non-null     float64
#  23  total_case_rate      32 non-null     float64
#  24  infection_tate(60-)  32 non-null     float64
#  25  infection_tate(60+)  32 non-null     float64
# dtypes: float64(19), geometry(1), int64(3), object(3)
# memory usage: 6.8+ KB

# %%
# GWR

# %%
ax = boro_xy.plot(edgecolor='white',column="total_cases",cmap='GnBu',figsize=(6,6))
boro_xy.centroid.plot(ax=ax, color='r',marker='o')
ax.set_axis_off()

# %%
boro_xy['centro']=boro_xy.centroid
boro_xy['X']=boro_xy.centro.x
boro_xy['Y']=boro_xy.centro.y
coords = list(zip(boro_xy['X'],boro_xy['Y']))

# %%
coords[0:5]
# Out:
# [(519297.6348074289, 166820.01149016235),
#  (533290.1539193918, 163541.24357427526),
#  (542895.5116070557, 165655.52134038546),
#  (513515.5055361106, 175643.2243196642),
#  (515887.9377702068, 181715.49561692882)]

# %%
boro_xy.head()
# Out:
#                            NAME SUB_2009 SUB_2006  \
# Area_code
# E09000021  Kingston upon Thames     None     None
# E09000008               Croydon     None     None
# E09000006               Bromley     None     None
# E09000018              Hounslow     None     None
# E09000009                Ealing     None     None
#
#                                                     geometry  blue_dist  \
# Area_code
# E09000021  POLYGON ((516401.600 160201.800, 516407.300 16...   3.443026
# E09000008  POLYGON ((535009.200 159504.700, 535005.500 15...   2.908372
# E09000006  POLYGON ((540373.600 157530.400, 540361.200 15...   2.637000
# E09000018  POLYGON ((521975.800 178100.000, 521967.700 17...   1.598901
# E09000009  POLYGON ((510253.500 182881.600, 510249.900 18...   2.013571
#
#            green_act  green_pas  obesity(age18+)  respiratory  coronary  ...  \
# Area_code                                                                ...
# E09000021    0.51207   0.464815          57.6050      83.2563   89.3540  ...
# E09000008    0.50500   0.584036          61.8092      96.4060   88.0417  ...
# E09000006    0.47000   0.478473          58.0292      83.4814   80.1178  ...
# E09000018    0.38250   0.564246          63.2337      95.9538  115.7913  ...
# E09000009    0.37750   0.553855          53.0091      89.0166   97.2686  ...
#
#            ln_total_cases  total_cases2  covid0_60  covid_60up  \
# Area_code
# E09000021       11.053015         25388    55474.0      7745.0
# E09000008       11.777748         54280   113581.0     16970.0
# E09000006       11.647474         47084    98314.0     16263.0
# E09000018       11.500580         37581    87660.0     11146.0
# E09000009       11.732663         47256   109930.0     14669.0
#
#            total_case_rate  infection_tate(60-)  infection_tate(60+)  \
# Area_code
# E09000021        37.579762            40.910030            23.904215
# E09000008        33.346981            35.796092            23.119848
# E09000006        34.667273            38.782643            21.231022
# E09000018        34.272380            36.373444            23.564423
# E09000009        33.934895            36.054444            23.621532
#
#                                   centro              X              Y
# Area_code
# E09000021  POINT (519297.635 166820.011)  519297.634807  166820.011490
# E09000008  POINT (533290.154 163541.244)  533290.153919  163541.243574
# E09000006  POINT (542895.512 165655.521)  542895.511607  165655.521340
# E09000018  POINT (513515.506 175643.224)  513515.505536  175643.224320
# E09000009  POINT (515887.938 181715.496)  515887.937770  181715.495617
#
# [5 rows x 29 columns]

# %%
###  model1 :total case reate

# %%
g_y = boro_xy['total_case_rate'].values
 
# 自变量
g_X = boro_xy[['blue_dist','green_act','obesity(age18+)','respiratory','coronary',"TB_incidence","Active","Females","income"]].values
 
"""# 坐标信息Latitude	Longitud
u = georgia_data['Longitud']
v = georgia_data['Latitude']
g_coords = list(zip(u,v))"""
 
# z标准化
g_X = (g_X - g_X.mean(axis=0)) / g_X.std(axis=0)
g_y = g_y.reshape((-1,1))
g_y = (g_y - g_y.mean(axis=0)) / g_y.std(axis=0)

# %%
g_X.shape
# Out:
# (32, 9)

# %%
g_y.shape
# Out:
# (32, 1)

# %%
gwr_selector = Sel_BW(coords, g_y, g_X,fixed=True,kernel='gaussian')
gwr_bw = gwr_selector.search(criterion='AICc')
gwr_results = GWR(coords, g_y, g_X,gwr_bw,fixed=True,kernel='gaussian').fit()

# %%
gwr_results.summary()
# Out:
# ===========================================================================
# Model type                                                         Gaussian
# Number of observations:                                                  32
# Number of covariates:                                                    10
#
# Global Regression Results
# ---------------------------------------------------------------------------
# Residual sum of squares:                                             14.234
# Log-likelihood:                                                     -32.444
# AIC:                                                                 84.888
# AICc:                                                               100.088
# BIC:                                                                -62.012
# R2:                                                                   0.555
# Adj. R2:                                                              0.373
#
# Variable                              Est.         SE  t(Est/SE)    p-value
# ------------------------------- ---------- ---------- ---------- ----------
# X0                                   0.000      0.142      0.000      1.000
# X1                                   0.130      0.209      0.621      0.535
# X2                                  -0.083      0.270     -0.308      0.758
# X3                                   0.150      0.277      0.542      0.588
# X4                                  -0.038      0.205     -0.185      0.853
# X5                                   0.235      0.259      0.907      0.364
# X6                                  -0.667      0.237     -2.820      0.005
# X7                                   0.173      0.250      0.692      0.489
# X8                                  -0.372      0.243     -1.531      0.126
# X9                                   0.508      0.251      2.025      0.043
#
# Geographically Weighted Regression (GWR) Results
# ---------------------------------------------------------------------------
# Spatial kernel:                                          Fixed gaussian
# Bandwidth used:                                                   92620.780
#
# Diagnostic information
# ---------------------------------------------------------------------------
# Residual sum of squares:                                             14.076
# Effective number of parameters (trace(S)):                           10.136
# Degree of freedom (n - trace(S)):                                    21.864
# Sigma estimate:                                                       0.802
# Log-likelihood:                                                     -32.265
# AIC:                                                                 86.802
# AICc:                                                               100.408
# BIC:                                                                103.124
# R2:                                                                   0.560
# Adjusted R2:                                                          0.346
# Adj. alpha (95%):                                                     0.049
# Adj. critical t value (95%):                                          2.046
#
# Summary Statistics For GWR Parameter Estimates
# ---------------------------------------------------------------------------
# Variable                   Mean        STD        Min     Median        Max
# -------------------- ---------- ---------- ---------- ---------- ----------
# X0                       -0.000      0.003     -0.008     -0.001      0.005
# X1                        0.128      0.001      0.126      0.128      0.130
# X2                       -0.083      0.003     -0.088     -0.083     -0.077
# X3                        0.150      0.001      0.148      0.150      0.152
# X4                       -0.039      0.002     -0.043     -0.039     -0.035
# X5                        0.236      0.001      0.233      0.236      0.238
# X6                       -0.667      0.001     -0.669     -0.666     -0.664
# X7                        0.175      0.003      0.168      0.175      0.181
# X8                       -0.370      0.003     -0.376     -0.370     -0.364
# X9                        0.504      0.002      0.500      0.505      0.509
# ===========================================================================

# %%
boro_xy['gwr_x0'] = gwr_results.params[:,0]
boro_xy['gwr_x1'] = gwr_results.params[:,1]
boro_xy['gwr_x2'] = gwr_results.params[:,2]
boro_xy['gwr_x3'] = gwr_results.params[:,3]
boro_xy['gwr_x4'] = gwr_results.params[:,4]
boro_xy['gwr_x5'] = gwr_results.params[:,5]
boro_xy['gwr_x6'] = gwr_results.params[:,6]
boro_xy['gwr_x7'] = gwr_results.params[:,7]
boro_xy['gwr_x8'] = gwr_results.params[:,8]
boro_xy['gwr_x9'] = gwr_results.params[:,9]

# %%
fig,ax = plt.subplots(nrows=3, ncols=5,figsize=(20,10))
axes = ax.flatten()

var_names =["coe_inter",'blue_dist','green_act','obesity(age18+)','respiratory','coronary',"TB_incidence","Active","Females","income"]
var_names1 = ['gwr_x0','gwr_x1','gwr_x2','gwr_x3','gwr_x4','gwr_x5','gwr_x6','gwr_x7','gwr_x8','gwr_x9']

for i in range(0,len(axes)-1):
    
    ax=axes[i]
    ax.set_title(var_names[i])
    boro_xy.plot(ax=ax,column=var_names1[i],edgecolor='white',cmap='PuBu',legend=True)
    
    #if (gwr_flter_t[i] == 0).any():
     #   boro_xy[gwr_flter_t[i] == 0].plot(color='lightgrey', ax=ax, edgecolor='white') # 灰色部分表示该系数不显著
 
    
    ax.set_axis_off()
    if i+1==7:
        axes[7].axis('off')
        
plt.show()
plt.savefig(os.path.join('img','GWR total.png'))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1183/2479156878.py in <module>
#       8
#       9     ax=axes[i]
# ---> 10     ax.set_title(var_names[i])
#      11     boro_xy.plot(ax=ax,column=var_names1[i],edgecolor='white',cmap='PuBu',legend=True)
#      12
#
# IndexError: list index out of range
